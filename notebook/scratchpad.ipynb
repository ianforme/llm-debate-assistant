# %%
from llm_debate_assistant.core.assistant import DebateAssistant
from llm_debate_assistant.core.orchestrator import DebateOrchestrator
from llm_debate_assistant.templates.style_cards import style_cards

# %%
assistant = DebateAssistant()
orchestrator = DebateOrchestrator(assistant)

# %%
xbw_version = await orchestrator.generate_opening_statement(topic="人工智能是否应该被严格监管？", side="正方", llm_as_judge=False, style_example=style_cards['gemini-xbw'])
# Out:
# ==========Stage 1: 生成立论框架...==========
#
# 规划立论框架 - 人工智能是否应该被严格监管？： 正方
# **************************************************
# ==========Stage 2: 基于立论框架搜寻所需资料...==========
#
# 资料搜寻 - 论点: 论点一：人工智能具有规模化与自治性带来的系统性风险，因而应被严格监管以防止重大伤害与外部性扩散。
# 论证: 人工智能系统能在极短时间和大范围内做出自动决策（如自动驾驶、算法交易、自动化内容生成），单点失误或滥用会迅速放大并产生连锁效应，造成人身伤害、经济损失或社会秩序破坏。市场自律与企业短期激励往往无法充分内部化这些外部性，信息不对称使公众难以评估风险。严格监管可通过风险分级、强制安全测试、入市许可、事故报告与责任追究等制度性手段将系统性风险降到可接受水平，从而更好地实现公共安全目标。
# 所需资料: 具体事故与滥用案例详查：如自动驾驶致死事故（Uber 2018 等）、与自动驾驶/驾驶辅助相关的多起碰撞争议；语音或视频深度伪造用于诈骗并导致财产损失的新闻报道；算法驱动的市场异常事件（如算法交易相关的闪崩案例）。;权威风险评估报告：牛津大学未来人类研究所、OpenAI 等关于AI系统带来系统性与长期风险的研究与政策建议文献。;监管与非监管情形的对比数据：在实施监管试点或强监管框架下高风险AI部署事故率、召回/禁用率或损失变化的实证资料（如某国对自动驾驶或医疗AI试点的效果评估）。;技术可审计性与安全方法的现状分析：对抗性鲁棒性、模型验证、独立第三方安全审计和强制测试方法的成熟度与局限性的学术与产业研究。;法律与经济学证据：关于外部性、信息不对称与企业激励不足导致市场失灵需要政府介入的理论与实证研究。
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 资料搜寻 - 论点: 论点二：人工智能对隐私、公平与民主构成实质威胁，只有严格监管才能提供有效保护与救济。
# ...

# %%
ys_version = await orchestrator.generate_opening_statement(topic="人工智能是否应该被严格监管？", side="正方", llm_as_judge=False, style_example=style_cards['gemini-ys'])
# Out:
# ==========Stage 1: 生成立论框架...==========
#
# 规划立论框架 - 人工智能是否应该被严格监管？： 正方
# **************************************************
# ==========Stage 2: 基于立论框架搜寻所需资料...==========
#
# 资料搜寻 - 论点: 论点一：严格监管能有效降低人工智能带来的系统性与重大安全风险
# 论证: 人工智能在交通、医疗、能源、金融与国防等关键领域具有放大效应和耦合风险，一旦失控会造成重大人员伤亡、基础设施瘫痪或国家安全威胁。通过严格监管（如风险分级、强制安全测试、上线前审查、持续监测与独立问责）可以在研发与部署环节识别并消除高危设计与缺陷，从源头上降低事故发生概率与后果规模，直接满足比较标准中对‘保障公众安全’的要求。
# 所需资料: 自动驾驶系统导致的致死或重伤事故调查报告（例如2018年优步自动驾驶致死事故等）;医疗人工智能误诊或误导临床决策导致严重后果的具体案例与官方调查结果;算法驱动的金融系统事件（如自动化交易导致的闪崩）及其损失估算;深度伪造或错误自动决策在大规模传播时引发的公共安全事件实例;政府或国际组织关于AI在关键基础设施与国防领域的风险评估报告与结论;对比研究：民航、医药等行业通过严格监管降低事故率和社会成本的历史数据
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 资料搜寻 - 论点: 论点二：严格监管可保护个人权利与民主价值，防止隐私侵犯与歧视性后果
# 论证: 人工智能依赖海量个人数据并在决策中嵌入历史偏见或进行大规模识别与分类，容易侵害隐私、加剧种族/性别/阶层歧视并压缩言论与政治参与空间。严格监管可通过数据最小化、用途限制、透明度与可解释性要求、禁用敏感场景以及有效救济与问责机制来防止或修正这些侵害，从而在促进技术利益的同时维护基本人权与社会公平，契合比较标准中对‘个人权利保护与社会公平’的衡量维度。
# ...
