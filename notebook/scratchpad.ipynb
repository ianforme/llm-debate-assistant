# %%
from llm_debate_assistant.core.assistant import DebateAssistant
from llm_debate_assistant.core.realtime_assistant import RealtimeAssistant
from llm_debate_assistant.core.orchestrator import DebateOrchestrator

# %%
assistant = DebateAssistant()
realtime_assistant = RealtimeAssistant()
orchestrator = DebateOrchestrator(
    assistant=assistant, 
    realtime_assistant=realtime_assistant
)

# %%
topic="台湾应废除私人移工中介制度"

# %%
pro_statement = """
谢谢主席，问候在场各位：
根据监察院2023年最新调查报告显示，私人中介已成为系统性剥削移工、制造社会问题的核心根源。今天，我方坚决主张台湾必须全面禁止私人移工中介。
大法官释字第740条明确指出，凡具有从属性劳动之契约，都应认定为劳动契约关系，以保障劳工权益。然而现实情况是，私人中介完全无视这一法律精神，肆意妄为。根据就业服务法规定，中介向移工收取的服务费第一年每月不得超过1800元，且不得预先收取。但2014年外籍劳工工作及生活关怀调查显示，94.4%的事业类移工需自行负担高额中介费，其中35.4%支付超过9万元；家庭看护工更高达85.8%需要付费，63.4%支付7万至9万元不等。（合适的类比）
这些违法收费往往迫使移工背负沉重债务。数据显示，59.8%的事业类移工和65.8%的家庭看护工为此不得不借贷。越南移工阮国非的悲剧就是最血淋淋的例证。他的父亲抵押土地向银行借贷5800美元才凑齐中介费。来台后，阮国非发现即便天天加班，所得薪资仍难以偿还债务，最终被迫成为逃逸外劳，并在新竹遭警察枪击身亡。私人中介正是移工逃逸问题的罪魁祸首。监察院2023年报告明确指出，"过高的仲介费"是移工逃跑的最大推力。当移工发现合法收入根本无法偿还债务时，成为"失联移工"打黑工反而成为他们无奈的选择。这些被迫逃亡的移工往往聚集在半导体园区等工地附近接活，过着提心吊胆的生活。在长期压力下，有些人甚至开始接触毒品，衍生出更严重的社会问题。
其次，私人中介的服务质量与收费完全不成正比。26岁的越南移工阿凯向亲友和台湾中介借款20万元来台工作，却被安排到完全不适合的大理石工厂。体重仅46公斤的他每天要搬运40公斤的大理石，在充满粉尘的环境中工作。当他提出调换工作的合理要求时，中介竟威胁要将其遣返。服务费倒是付了，那我请问服务在哪里？
近年来，私人中介行业普遍存在炒短线心态。18年来人力仲介牌照数量增长162%，但其中一半是"领照不营运"的空壳公司，专门用来规避政府处罚。业者直言："做两年就停牌，超收费用也无所谓，反正国税局三年才查税。"这种投机心理导致整个行业恶性循环。其次，小微中介恶性竞争加剧乱象。2019年数据显示，90%的中介公司员工少于5人，99%少于10人。这些小型中介主要依靠"海外收款"维持运营，甚至不惜以"每月退佣5000元"等不正当手段抢夺客户。长欣利国际人力顾问总经理廖浩彬指出："只要你不能让企业发展品牌，它就不会走向良性竞争。"
「買工費」氾濫，可是勞動部究竟有多少開罰的案例？難以收集證據、無法申訴與裁罰的案例比比皆是，這一點下至地方勞工局，上至中央勞動部都知道，這是私人仲介壟斷移工就業市場的結構性問題，完全不是有罰則便可以解決的事情！当换牌成本远低于违法罚款时，私人中介自然选择不断更换牌照来逃避责任。这种制度漏洞使得违法成本极低，而获利空间巨大。
综上所述，私人移工中介已经证明是台湾社会的一颗毒瘤。它们通过违法收费、压榨劳工、制造社会问题来牟取暴利，其商业模式本质上就是建立在剥削弱势群体之上。现行的部分监管措施已被证明完全无效，唯有全面禁止私人移工中介，改由政府建立公立、透明的招募管道，才能真正解决这一结构性剥削问题。
"""

# %%
con_statement = """
​谢谢主席，问候在场各位：
我方认为台湾不应废除私人移工中介制度。
首先现状下中介行业已大有改善，绝非对方口中单纯鱼肉移工的负面行业，并无全面取缔的必要。
一方面，移工议价权上升。随着日韩等国以更优待遇竞争移工，台湾市场不再是雇主一方独大的买方市场，移工本身争取权益的能力增强，母国政府也加强了保护。比如菲律賓政府颁布RA10022法案，隔年開始嚴格取締超收仲介費，鼓勵移工檢舉，並從官方施壓要求仲介退款。印尼政府一步要求海外雇主支付全部仲介費用。在印尼政府壓力下，台灣勞動部在聘倔外籍看護工的定型化契約裡明確規範雇主應付曹用。
另一方面，国际审查压力促使中介趋向透明与合理经营。在人权组织和上游欧美买家的要求下，对移工「零收费」正成为主流趋势。台湾GDP的63%以及超過一半以上的工作机会都與全球供應鏈有關。许多制造商需通过人权组织RBA的审查，一旦RBA審查員發現外籍移工支付任何一筆費用，代工廠就會被記重大缺失，訂單即刻暫停出貨。人力中介羅盈勝表示，RBA審查員的調查清單多达200項，且要求一對一訪問移工，甚至要看國外合作仲介的財報資料，他直言「要是我不合格，連帶我的客戶也會受到影響，它可能就迫退出合格的供應商名單，沒有一家仲介敢讓客戶掉出合格名單」。
其次，若彻底废除移工私人中介，官方没有能力承担大量移工的就业问题。
现行的直聘中心几乎形同虚设，且很难推动与别国政府对接。截止2023，台湾直聘制度的使用率极低，仅占整体移工引进的2-3%，比例最高的年度也僅11.9%，还在2018年降至1.13%，根本无法填补私人中介退场后移工引进的职能空白。加上国对国模式合作时，需高度取决于母国对移工来台的态度。例如，印尼政府就明确表示，他们只允许家庭看护工续聘时选择直聘，首次入境的印尼移工仍需中介协助；越南方面也表示，劳工习惯通过中介办理手续，对国对国模式合作意愿低下。对方如何强行改变移工来源国的态度后续也需交代。
在此基础上，强行废除私人移工中介制度还将承受以下弊害：
第一，是丧失现状下中介从业者提供的高效、优质、多元的服务。现状下，中介行业为移工和雇主提供了重要的服务和培训。比如中介业者吴董成立了训练所，培训中文、烹飪、看護、居家整理等四十多项技能，甚至提供福利基金帮助患病移工看病。中介业者許家畯在几年前争取大客户的最后一轮中被要求找到一間能容納五百人的宿舍，他意识到大公司对于中介的服务有了更多需求，于是找股东投资，向银行贷款将近四亿来盖移工宿舍，据他估算，即使宿舍顺利住满人，也要二十年才能回收成本。他希望通过长线的品牌效应，让有需求的雇主自然的选择他。
反观政府直聘模式，勞動部《移工管理及運用調查報告》显示：超六成雇主认为直聘无后续代办及管理业务，因此对此兴致缺缺。加上移工相关法律繁琐，不时有雇主因不熟悉法令及後續業務辦理而遭處分。这些问题对需要雇聘护工的老年雇主而言更是难上加难。；即使以国对国模式的成熟案例韩国EPS为例，该制度实行多年，仍被诟病效极差。牛津大学调查显示：参与调查的韩国雇主尤其对 EPS 行政流程的低效率和漫长的等待时间以及该系统的劳动力匹配能力感到不满，获准前往韩国工作的移民工人中至少有 3成需要等待一年才能前往韩国，而 27.4% 则需要等待长达 2 年。
第二，是对中介从业者工作权的过度侵害，同时造成资源浪费。宪法第十五条明确保障人民工作权。在直聘中心刚成立时，就发生了一次中介业者的游行抗议，近千名仲介從業人員抗議勞委，限縮業者的生存空間与自由，直聘中心成立后，仲介業者將损失新臺幣2.7億 的商机。官文傑表示，直聘中心招標過程，排除私立就業服務機構及其分支機構參與，不符合憲法所規定平等原則。再加上勞委會一年編列 新臺幣 2,540 萬元作為直聘中心預算。如果要全面废除私人中介，无疑是对中介从业者工作自由的更大侵害，而付出的财政代价也将数倍上升。
综上
"""

# %%
pro_examples = {
    "台湾中介普遍存在经济剥削": """王裕衡(2017: 33)觀察到，2016 年後，除非引進的是越南移工，否則雇主幾乎沒有籌碼用聘倔許可跟仲介换取回扣;我們訪問的台灣仲介表示，聘倔越南移工時，仲介提供雇主的回扣仍然可能喊到一個人六、七萬。對台灣仲介來说，從越南引進移工利潤較高，因而成為傅統產業招工的首選來源。根據受訪的移工團體表示，買工費的金額不等，大約在五千到兩萬之間，宣稱加班時數高的工作，可能收到四萬五、五萬甚至八萬。""",
    "台湾中介普遍存在经济剥削（近年发展）": """2016年「三年出國一日條款」被廢除後，仲介業者開始向「在台轉換工作」的移工收取勞動部已明定不得收取的「買工費」，一份工作從兩萬到九萬都有，而且過程中不留痕跡、難以蒐證。移工可以選擇不付錢，但代價是找不到工作，最後只能逃跑或被遣返回國。特別是去年十月疫情結束後，國境解封重新開放引進移工。仲介業者為了彌補疫情期間少賺的仲介費，從移工身上剝皮賺錢的手法推陳出新、變本加厲，買工費、辦件費、面試費、轉換費、訂金、尾款，各種違法收費巧立名目。如今，移工的就業市場違法收費氾濫，尤其是製造業移工幾乎到了「每個工作都要買工費」的地步。勞動部從2016年開始，對於仲介違法收買工費，始終只空泛地回應「會管控」、「有證據就開罰」，實際上卻完全束手無策；七年後的今天，違法收費從單純的買工費，逐步衍生出辦件費、面試費、轉換費、訂金、尾款，收費項目越分越細；整個收費體系擴展到介紹人、傳話人、車手、人頭帳戶，分工也越來越綿密；一個在勞動部口中被嚴格禁止的行為，到今天幾乎演變成「違法收費成為移工就業市場的常態」。""",
    "移工因为怕还不起中介费被性侵都不敢反抗": """根据卫福部最新统计，2007年至2018年底，有1076件移工遭性侵案件被通报，其中以印尼移工最大宗；行业别以「家庭看护或帮佣」最多为836件，加上养护机构的看护，总计863件，占比80.2％。显见女看护遭性侵的严重性。但社工人员推测，移工因害怕丢工作，无法偿还仲介费，多数不敢报警或通报，官方数据并未纳入「黑数」，因此性侵案不止于此。当性侵案发生时，仲介通常仅口头劝说雇主，却不报警，甚至会对移工语带威胁，「妳要申诉吗？妳没有证据，小心被告诬告而坐牢。」连移工母国的仲介都会向家人施压。陈秀莲曾处理一起印尼看护性侵案，受害者要告老板，结果在台工作的阿姨请她赶紧与家人联系。""",
    "中介靠剥削赚得盆满钵满": """華視記者訪問到仲介業者，說仲介一名仲介除了每個月1萬5千到2萬元的底薪外，還有抽成獎金，以進一名移工為例，國外仲介公司會給本國仲介公司進工獎金，仲介一次平均可以拿到3萬元，還有，雇主合約金每次可拿1萬元左右，再加上每個月移工會給仲介服務費約1千元左右，三筆獎金加起來就有4萬1千元（每進一名移工），如果接到大工廠的單，一次進2、30位移工，一個月破百萬都不成問題。""",
    "中介的压迫直接导致移工逃跑": """監察院2023年的調查報告指出，「仲介」佔了移工逃逸原因的大宗：「過高的仲介費」是移工逃跑的最大推力；而結構性問題的部分，7項裡面有3項與仲介有直接相關：「仲介費用脫離政府的規範」、「不受控管的仲介業者」及「仲介品質參差不齊」。當移工面臨 高額仲介費導致其無法償還，或收入不如預期時，成為「失聯移工」去做非法工作反而是更好的選擇，非法雇傭移工的雇主來自最嚴重缺工的產業，例如農業，儘管成為失聯移工意味著失去法律保障與被遣送回國的風險，但為了更高的薪資，不少移工還是願意放手一搏。""",
    "中介为什么必然会剥削": """2019年終止營業與新登記的人力仲介公司，員工數在5人以下的佔9成，10人以下有9成9，全都是小規模的仲介公司。這類小仲介是最容易違法的一群。「他們幾乎都靠收海外款活下來的，你看他每年才引進幾個人，還要繳300萬押金進去，為什麼？他只要收幾筆海外款就回來了，」胡中裕接著說。「從去年開始，跑單幫的盲目想要錢而已，只要你工廠請10個（外勞），他就說每個月退5,000給你（雇主），要不要？」他抱怨小仲介為了搶訂單而削價競爭，讓本來惡名昭彰的人力仲介業更為混亂。""",
    "中介违法行为难以被监管——换牌照": """國立臺灣大學社會學系调查显示：因應上述國家管制，台灣仲介發展出彈性换牌的營策略，也造成退場率高的假象。我們訪問的台灣仲介業者，幾乎所有仲介都利用親人或員工名義，申請多張牌照，其中一家仲介甚至握有七張牌照。一旦出現違法事端，仲介便能在政府裁罰之前終止營業，逃避停業處。許多仲介都並将容易引起逃跑的廠商(如動條件特别差、加班時數少)技術性地集中放在某一張牌照，即使後來被停牌，也不影其他牌照繼續運作。""",
    "中介评级系统失效": """华泰国际人力资源有限公司负责人Amy，从事仲介17年，在她的记忆里，仲介评鉴就是走个过场。以前要用彩带、红布条欢迎评鉴委员莅临，过程包含抽查公文是否齐全，以及抽问仲介业相关法规，如：「性侵案件要打哪支电」、「移工有问题打哪只电话」等。她直言，只要事先备齐文件、熟背题目，就能拿到A级，这样的评鉴根本不具参考价值。因此仲介业者内部也认为，评鉴制度无法有效区别仲介优劣。从评鉴委员到评鉴方式，皆不够完善的情况下，导致评鉴等级失去参考价值，台湾国际劳工暨雇主和谐促进协会顾问张姮燕就曾深受其害。回忆先前被A级仲介欺骗的经历，她仍感到忿忿不平。当时她还打电话到劳工局，询问，为何评鉴A级却是不良仲介，没想到了劳工局竟回覆：「你怎么会相信评鉴制度？」让她从此对评鉴制度失去信任。""",
    "中介违法行为难以被监管——让母国牛头收钱与跨国转移": """儘管台灣與越南政府都有規範仲介費用，但只要為數眾多的中介者從中操縱資訊，就能使灰色的收入空間繼續存在，並讓所有的監管手段都效果不彰。當人權團體質疑台灣的高額仲介費時，勞動部對此回應很一致：「我們有建議來源國收一個月的薪資，但仲介費是在越南收的，我們也很難介入，」薛鑑忠說我們在採訪時接觸一位貸款公司背後的台灣老闆，親眼所見這位中間人的保險箱小金庫裡，隨時存放著一摞摞台幣、美金、與越盾現金。當越南仲介要將這筆海外的回扣金匯回台灣時，他們在越南拿美金給這名中間人，由他匯給台灣的白手套，再從台灣銀行帳戶匯給台灣仲介。這筆錢跨國多次轉匯後，讓兩地政府都難以追蹤，從而削弱打擊高額仲介費的努力。"""
}

# %%
con_examples = {
    "良心中介": """從二〇一八年開始，他陸續找股東投資，向銀行貸款將近四億來蓋移工宿舍，據他估算，即使宿舍順利住滿人，也要二十年才能回收成本。「我想將來這些雇主都會需要移工宿舍，那我在園區裡有一棟宿舍，是完全符合政府規範的，而且移工也方便，總比你把他們四處放在各個宿舍好。」許家畯看準移工宿舍的商機，「使用宿舍的雇主，就算原本不是我服務的客戶，我有機會能夠慢慢地接觸，讓他們轉給我服務。」許家畯經營的仲介公司，管理一千三百名移工，七成是廠工，客戶多是工具機或金屬製造業，是典型的中型規模仲介公司。許家畯願意投資的原因，來自幾年前的一場失敗。當時他正在爭取大立光這個客戶，這家公司以代工蘋果（Apple）手機的鏡頭而聞名，作為蘋果供應鏈的一環，它們對於選擇合作的仲介公司有更高要求，包含提供宿舍舍監、清潔人員和二十四小時常駐工廠的翻譯。好不容易，他與其他三家仲介闖進最後一輪，客戶給的最後一個考題是找到一間能容納五百人的宿舍。""",
    "人权组织施压能良币驱逐劣币": """仁寶電腦位於桃園平鎮的工廠，有400多名越南移工集體罷工。當天中午，仁寶緊急派出高層協商，下午4點，仁寶向股東發布重大訊息說，公司「以善盡企業社會責任為己任，積極與移工協商」。1小時後，勞資雙方簽署11點的和解協議。9小時內，罷工火速落幕。（要屬一年前、2019年5月在新北市美堤食品廠的事件：74名移工參與罷工，然而，2個月後，美堤突然解雇5名當初參與罷工的工人。事後，一名被解雇的女工被迫返回越南，直到上飛機前，仍在擔心仲介費的貸款還不完。）仁寶電腦罷工罢工成功的原因是，仁寶是蘋果電腦全球第二大代工廠，僅次於富士康，他們都被國外買家要求改革工人的工作條件，避免觸及任何與人口販運相關的風險，否則，他們將可能要退出合格供應商名單。這些改革措施包括：大幅縮短工人的工作時間、改善工作安全條件、減輕移工的仲介費負擔等。""",
    "人权组织施压让雇主必须选择好中介": """南俊前人資經理L表示，「就像我們的客戶來稽核我，我也會更加要求合作的人力仲介；不只對台灣仲介，連國外合作的仲介我也要嚴格檢視。」L今年剛辭職，去年他由台灣仲介陪同，已經跑過3次菲律賓，仔細調查欲合作的海外仲介，「我們引進一個工人，付給海外仲介的費用在3萬5（新台幣）上下，」L接著說，「既然錢是我出，萬一工人進來台灣以後，被問到有超收費用，我就要他（海外仲介）賠償。」善用供應鏈的壓力甚至是壓迫，台灣廠商同樣用供應鏈方式管理兩地仲介裡的灰色收入。""",
    "禁止私人中介损害中介业者工作权": """在 2008 年 1 月，針對直接聘僱中心的成立，近千名仲介從業人員今走 上街頭，高喊「盧天麟下台！」的口號，抗議勞委會成立直接聘僱中心，限 縮業者的生存空間。官文傑表示，直聘中心招標過程，排除私立就業服務機 構及其分支機構參與，不符合憲法所規定平等原則。再加上勞委會一年編列 新臺幣 2,540 萬元預算，作為直聘中心運作的經費，事實上，直聘中心所負 責的工作，仲介業者早已進行中，砸下這筆錢，無異浪費公帑。黃杲傑強 調，直聘中心缺乏後續服務資源，勢必衍生更多勞資糾紛。據瞭解，直聘中 心一年至少服務 5,000 件申請案，仲介業者將短少新臺幣 2 億 7,000 萬元的商机。""",
    "移工母国不配合国营中介": """跨國勞力遷移，涉及到雙方政府的合作，並且同時也牽動到雙方所形成 的遷移產業與自身政府的關係，經常無法一概而論。上述的爭議，除了對於 勞工的保護，可能也牽涉到對於雙方仲介產業，誰「讓利」較多，以及各自 承受國內仲介產業壓力的問題。臺灣推動直接聘僱制度後，印尼及越南雖未反對，但亦尚未有積極合作。根據直聘中心陳昌邦主任的說法，印尼勞工以家庭監護工為主，目前僅開放重新招募的印尼家庭監護工得以透過直接聘僱管道，對於初次招募的印尼監護工則尚未開放，理由是印方認為，家庭監護工是單獨的進入家庭之中，需要有仲介代為管理。而與越南專案選工的合作上也尚無法順利推行。據越方的說法是，越南勞工習慣付費透過仲介公司協助辦理。""",
    "弱势群体用不明白国营中介": """（需要看护的）老年雇主很难操作复杂的流程：目前主要以在臺移工的接續聘為主。由於目前已經限縮到僅剩臺北一處，這造成了雇主需要郵寄或親自到臺北辦理的不便。雖然直聘中心也提供線上申請，但除了熟悉電腦的使用，還必須有自然人憑證才能登錄，還要會掃描文件應儲存成正確格式，大大提高使用這個介面的門槛，尤其需要聘雇看護的人，年紀可能在五六十歲以上，他們不熟悉這些界面的操作。""",
    "韩国废除私人中介后，引入移工效率变低": """The study found that at least 30 per cent of the migrant workers approved to work in Korea were made to wait one year before they could depart for Korea, and 27.4 per cent were made to wait up to 2 years (Ebert Friedrich Stiftung 2011:9).牛津大学研究发现，获准前往韩国工作的移民工人中至少有 30% 需要等待一年才能前往韩国，而 27.4% 则需要等待长达 2 年（Ebert Friedrich Stiftung 2011:9）。""",
    "国家来做中介效率低": """只有73.3%的EPS公司找到了匹配，只有50%的EPS帖子找到了匹配。""",
    "韩国废除私人中介，也没有杜绝高额中介费": """Similarly, ST, a 30-year-old Vietnamese male, paid a broker USD 10,500 to come to South Korea in January 2007. According to him: “If you go through the government, you normally have to wait at least three years. But if you want to go immediately, then you have to pay a broker who knows people at the Ministry of Labour in Vietnam.国际特赦组织的报道：同样，30岁的越南男子ST于2007年1月向一位中间人支付了10,500美元，来到韩国。据他说：“如果通过政府途径，通常至少要等三年。但如果你想立即出发，就必须付钱给一位认识越南劳动部的人的中间人。”"""
}

# %%
pro_examples = "\n\n".join([f"用途:{k}\n论据{v}" for k, v in pro_examples.items()])
con_examples = "\n\n".join([f"用途:{k}\n论据{v}" for k, v in con_examples.items()])

# %%
orchestrator.oregon_interrogation_practice(topic, "反方", con_statement, con_examples, 60)
# Out:
# 总结辩手发言...
# 🎙️🟢 Mic active
# Connected to OpenAI WebSocket.
# ⚡️ Received WebSocket event: session.created
# ✅ session.update 已发送（系统设定生效）。
# ✅ response.create 已发送（已要求模型基于背景开始发言）。
# ⚡️ Received WebSocket event: session.updated
# ⚡️ Received WebSocket event: response.created
# ⚡️ Received WebSocket event: response.output_item.added
# ⚡️ Received WebSocket event: conversation.item.created
# ⚡️ Received WebSocket event: response.content_part.added
# ⚡️ Received WebSocket event: response.audio_transcript.delta
# ⚡️ Received WebSocket event: response.audio_transcript.delta
# ⚡️ Received WebSocket event: response.audio_transcript.delta
# ⚡️ Received WebSocket event: response.audio_transcript.delta
# ⚡️ Received WebSocket event: response.audio.delta
# 🔵 Received 4800 bytes, total buffer size: 4800
# ⚡️ Received WebSocket event: response.audio.delta
# 🔵 Received 7200 bytes, total buffer size: 12000
# ⚡️ Received WebSocket event: response.audio.delta
# ...
