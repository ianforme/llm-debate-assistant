# %%
from llm_debate_assistant.core.assistant import DebateAssistant
from llm_debate_assistant.core.realtime_assistant import RealtimeAssistant
from llm_debate_assistant.core.orchestrator import DebateOrchestrator
from llm_debate_assistant.utils.style_cards import gemini_ys_style

# %%
assistant = DebateAssistant()
realtime_assistant = RealtimeAssistant()
orchestrator = DebateOrchestrator(
    assistant=assistant, 
    realtime_assistant=realtime_assistant
)

# %%
orchestrator.generate_opening_statement_sync(
    "人工智能的广泛应用是/否会加剧教育不平等",
    "正方",
    gemini_ys_style,
)
# Out:
# ==========Stage 1: 生成立论框架...==========
#
# 规划立论框架 - 人工智能的广泛应用是/否会加剧教育不平等： 正方
# **************************************************
# ==========Stage 2: 基于立论框架搜寻所需资料...==========
#
# 资料搜寻 - 论点: 基础设施与接入不均：数字鸿沟会使AI教育资源集中于富裕与城市群体，从而扩大教育差距。
# 论证: 教育类AI工具依赖终端设备、稳定网络、电力与持续维护。低收入家庭与农村或落后地区常缺乏这些基础条件、也承受订阅与更新费用的限制，导致无法享受AI带来的个性化教学、即时反馈与扩展资源。与此同时，资源充足的学校和家庭更易率先采购并有效整合AI，使其学生获得额外学习收益。随着时间推移，这些即时优势会累积并扩大相对差距。
# 所需资料: 按收入/城乡/地区划分的家庭互联网接入率和终端（电脑/平板/智能手机）拥有率数据;学校之间在网络带宽、终端设备与数字资源投入的比较数据（公私校差异）;随机对照试验（RCT）或实证研究，显示AI辅导/自适应系统对学生成绩或学习行为的效果及效果大小;AI教育产品的采购、订阅与维护成本分析以及学校预算约束案例;已有地区或学校在引入AI后出现的学习成果分化或利用率差异的案例研究与统计
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 资料搜寻 - 论点: 算法偏见与内容适配不足：AI在评估与教学上的偏差会对弱势群体产生系统性不利，深化不平等。
# 论证: AI模型性能依赖训练数据与开发资源；若训练集主要来源于主流文化、标准语言或优质学校样本，模型在处理少数群体、方言、低资源语言或有学习障碍的学生时性能下降。自动评分、能力分层或学习路径推荐若带有偏差，会把弱势学生置于低期望或低质量路径，减少他们获得教师关注与优质资源的机会。优质的模型本地化与持续监督需要人力与资金，资源充足方更能保障模型公平性，从而放大差距。
# ...
