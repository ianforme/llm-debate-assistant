# %%
import asyncio
from llm_debate_assistant.main import match_preparation, simulate_match


topic = "The rise of artificial intelligence is a threat to humanity."
preparation_results = await match_preparation(topic)
simulation_results = await simulate_match(topic, **preparation_results)
print(simulation_results)
# Out:
# 开始赛前准备：The rise of artificial intelligence is a threat to humanity.（LLM教练=True）
#
# 正在准备正方框架及立论...
#
# ==========Stage 1: 生成立论框架...==========
#
# ==========Stage 2: 基于立论框架搜寻所需资料...==========
#
# ==========Stage 3: 生成立论初稿...==========
#
# ==========Stage 4: 基于教练审核意见修改立论...==========
#
# ==========Stage 5: 基于示例优化写作风格...==========
#
# 正在准备反方框架及立论...
#
# ==========Stage 1: 生成立论框架...==========
#
# ==========Stage 2: 基于立论框架搜寻所需资料...==========
#
# ==========Stage 3: 生成立论初稿...==========
#
# ==========Stage 4: 基于教练审核意见修改立论...==========
#
# ==========Stage 5: 基于示例优化写作风格...==========
#
# 开始比赛模拟
#
# 正方二辩正在思考...
#
# 反方二辩正在思考...
#
# 正方三辩正在思考...
#
# 反方三辩正在思考...
#
# 反方四辩正在思考...
#
# 正方四辩正在思考...
#
# 评审正在打分...
#
# {'正方一辩立论': '首先对关键词作出限定。在本辩题中，“应该”指在道德、法律与公共政策层面应当采取某项措施；“废除”指通过立法或司法实践取消既有法律或制度使其不再生效；“死刑”指国家经司法程序对被定罪者实施剥夺生命的极刑。比较标准是以公共利益的综合最大化为准：在不降低社会安全的前提下，哪个方案能最大限度减少司法不可逆错误与对基本人权的侵害，并提升司法正当性与社会信任，哪个即为优先。基于此标准，我方提出三点立论。\n\n第一，废除死刑可根本消除不可逆的司法错杀风险，从而减少总体社会伤害。论证是：任何司法体系都会有错判的可能，而死刑一旦执行就无法挽回，因此即使错判概率看似低，其不可逆成本极高。实证证据支持这一点。2014年发表于PNAS的研究通过生存分析估计，如果所有死刑判决无限期维持，至少有约4.1%的死刑受刑者最终会被官方平反或撤销判决。这一量化结果说明在现行体制下错杀风险并非抽象而是实在的错误成本。与此同时，具体个案进一步证明了这种风险并非罕见。Kirk Bloodsworth是第一位通过事后DNA鉴定从死囚中被平反的人。案件记录显示目击证人误认与政府不当行为是导致错误判决的主要原因，DNA检测最终排除其罪责并于1993年获释与赦免。上述定量估计与个案结合，说明继续执行死刑意味着国家可能不可逆地剥夺无辜者生命，而以长期监禁等替代惩罚则可保留威慑与防护功能同时消除该不可逆风险。\n\n第二，保留死刑以“威慑暴力犯罪”为理由并无坚实的实证基础。论证是：若死刑在降低严重暴力犯罪方面没有稳定且显著的优势，那么所谓公共安全利益不足以抵消其高昂错误与人权代价。权威综述给出明确结论。2012年美国国家研究委员会就“死刑威慑”问题的综合报告结论是：迄今的实证研究无法为死刑是否影响凶杀率提供有用证据，且现有研究普遍未能把非死刑替代（如无期徒刑）考虑进去，无法回答政策的关键对比问题。此外，2009年对顶级犯罪学家的问卷调查显示，绝大多数受访专家认为实证研究并不支持死刑在长期监禁之上具有额外威慑效果。两项证据一起表明，主张以死刑换取更高公共安全的论据缺乏稳健支持。\n\n第三，废除死刑有助于维护生命权、提升司法正当性与国家国际形象，长期利于社会信任与治理合法性。论证是：生命权是最基本的人权，国家以司法方式剥夺生命在道德与国际话语中极易被视为不可逆且有违尊严的行为，从而削弱司法的道德权威。人权组织与国际机关对此持明确立场。国际特赦组织指出死刑侵犯生命权并将其称为“最残酷、不人道和有辱人格的惩罚”，并记录全球长期的死刑与撤销案例以证明其不可逆风险。同时，联合国大会于2007年通过的决议呼吁保留死刑的国家建立执行暂停并尊重国际人权保障，这反映出国际社会对废除或限制死刑的持续压力和规范趋向。尊重人权、提升程序正义与国际合法性，有助于增强公众对司法的信任，进而利于长期的社会稳定。\n\n综上所述，按照以公共利益综合最大化为比较标准，废除死刑在消除不可逆错杀风险、在缺乏确凿额外威慑证据的情况下不降低公共安全，并能提升司法正当性与国际形象三方面均占优，因此我方主张：应该废除死刑。', '反方一辩立论': '首先，对关键词作出界定并提出比较标准。在本辩题中，“不应该/应该”系指对法律是否应当采纳之政策判断；我方立场为“反方”，即主张不应废除死刑；“废除”意指通过立法于制度层面永久取消死刑；“死刑”指国家依法剥夺罪犯生命之极刑，其关键属性为不可逆与极端惩罚性。衡量标准为“社会整体利益（公共安全、司法正义与受害者权益）”：我们须比较废除与保留何者更能降低严重暴力犯罪、实现刑罚相称并维护受害者与社会安全。基于此标准，我方提出三点立论。\n\n第一，保留死刑具有实际之威慑与预防效果，因而可降低严重暴力犯罪，增进公共安全。支持此点之实证包括Dezhbakhsh、Rubin与Shepherd对美国县级“后禁死令”面板资料与联立方程之计量研究，报告指出每一次处决平均可减少约18起谋杀，误差区间约正负10起；另有Mocan与Gittings基于1977–1997年州级面板之分析，发现每多执行一次可减少约5至6起凶杀，且在控制州别特征后仍具稳健性。上述两项研究分别以更精细之县级面板与长期州级面板检验，均显示处决率与较低凶杀率之间存在显著之负相关，说明作为一种被感知且可量化之极端刑罚，执行死刑能通过降低高危主体实施最严重暴力之概率，为公共安全带来实质回报。\n\n第二，死刑体现刑罚相称与司法正义。对于极端残暴之谋杀等最严重罪行，保留死刑更能满足社会对正义之基本期待并维护司法权威。哲学与法律传统为此提供理论与制度依据：康德明确主张以“等价”之回应对谋杀实施死刑，其断言“若犯谋杀罪，则应被处死”，为报应式相称正义提供道德基础；在制度层面，美国最高法院于Gregg v. Georgia一案指出，若辅以加重/减轻情节之审查、分阶段审判及上诉等程序保障，死刑并非本质上违反宪法，且可在对某些极端罪行表明“强烈谴责”与维护社会秩序之正当性。由此可见，依相称原则与维护法治权威之比较标准，完全废除死刑恐使司法对最严重罪行之回应失去与罪行严重性相当之手段，进而损害受害者及公众对于司法正义之信任。\n\n第三，面对此类极端危险分子及监狱内外持续犯罪之实务风险，死刑提供不可替代之最终隔离保障，有助直接保护社会与受害者。联邦统计显示，出狱在押人员之重犯率偏高；美国司法统计局2018年报告指出，州监释放者中68%于三年内被重新逮捕，九年内达83%，其中暴力释放者再次实施暴力之概率显著；此外，联邦调查局亦指出監獄中之腐败、走私通讯工具及监管漏洞，可能使在押人员持续参与或指挥犯罪活动，削弱僅以長期監禁即可徹底阻斷危害之假设。上述证据说明：監禁并非对所有极端个体皆能保证绝对无害，部分有组织犯罪頭目或高度危险犯人在狱中仍可能维持外部联系或受外界渗透。在此现实下，作为一项最终且无法被外部干预逆转之隔离手段，死刑对少数但危害极大的个体，能直接提升公共安全并保护潜在受害者。\n\n综上，依“社会整体利益（公共安全、司法正义与受害者权益）”之比较标准，保留死刑在减少最严重暴力犯罪、实现刑罚相称与提供对极端危险者最终隔离等三方面均具重要价值。基于此，我方主张在完善程序保障与严格适用之前提下，不应废除死刑。', '正方二辩反驳': '《刑罚政策论争》一开始，对方便将衡量标准限定为“公共安全、司法正义与受害者权益”，并据此主张保留死刑。我方承认公共安全的重要性，然任何中立比较必须将不可逆错杀与基本人权置于同等地位；若将这一关键指标排除在外，则标准本身已偏向于保留死刑。事实表明，制度性的不可逆错误并非抽象风险：2014年PNAS之研究估计，在现行制度下约有4.1%的死刑判决最终会被撤销或平反；一系列经DNA证实之冤案（例如Kirk Bloodsworth）亦明确指出，死刑一旦执行，错误即无法挽回。既然“社会整体利益”包含此类不可逆之巨大代价，对方无权将该关键指标排除后再要求我方证明公共安全受损。\n\n第一，关于所谓威慑效果，对方援引若干面板研究以论证处决次数与凶杀率负相关，但此类研究在学界具重大争议。权威综述（美国国家研究委员会2012年）明确指示，现有实证并不能可靠回答死刑是否较无期徒刑等替代措施具有额外威慑力。即使在美國的若干研究中，显示正相关之结果对规范选择极为敏感；一旦加入合理控制或以替代刑罚作比较，其显著性往往不复存在。换言之，对方未能证明在与“无期徒刑且不得假释、提高定罪确定性、强化执法等替代政策”比较下，死刑仍具独特且可外推之威慑优势，故以“威慑”作为保留死刑之决定性理由，缺乏可资采信之证据基础。\n\n第二，关于“不可替代的隔离功能”，对方以一般再犯率及监狱走私为由，断言长期监禁无法保障社会安全，但他们混淆了“出狱者再犯”与“被判无期不假释者在押期间仍能指挥外部犯罪”之分别。现代监狱管理可藉特殊监管单元、通信封锁、情报追踪等措施，大幅降低在押者对外之危害可能性。将个别监管漏洞视为必须采用不可逆性刑罚之理据，忽略了修复监管、投入资源及其他替代路径之可行性與成本效益，乃以偏概全之政策判断。\n\n第三，对方以“相称报应”为优先价值，但在公共政策层面，价值须经权衡：报应之感受固然值得尊重，然不可凌驾于避免国家造成之不可逆错误与维护基本人权之上。若所谓“司法权威”倚赖一套可能导致无辜被剥夺生命之制度，则此类权威并非稳固，反而脆弱且代价高昂。因此，单以报应为优先而忽视不可逆风险与人权保障，实不足采。\n\n最后，除非对方能提出经得起方法学检验且直接比较死刑与可行替代方案在降低暴力犯罪之边际效应的确凿证据，并能证明在现实监狱與司法条件下不可逆错误可被降至可忽略之水准，否则其主张保留死刑可带来净社会利益的论断，难以成立。基于对不可逆风险、证据不确定性及替代措施可行性之综合考量，我方认为废除死刑更能实现社会整体利益之长期最大化。', '反方二辩反驳': '各位评判、各位朋友，我方先将对方之核心主张概括如下：对方以“在不降低社会安全的前提下，优先减少不可逆错杀与人权侵害”为比较标准，进而主张废除死刑，其理由集中为三点：一、死刑存在不可逆错杀之风险；二、缺乏可靠威慑证据；三、废除可提升生命权与司法正当性。下面我将依总—分—总之结构，逐点予以驳斥，并提出较为中性的衡量框架。\n\n第一，对方所设之比较标准并非中立，而是预先将“社会安全”设为不可降低之前提，并将“消除不可逆错杀”置于优先地位，实质上以一方价值选择作评判规则，造成定义上之偏颇。公平之比较应将公共安全、司法正义与受害者权益一并置于天平，允许证据衡量各自利弊；反之，要求保留方首先证明在所有情形下 ...
